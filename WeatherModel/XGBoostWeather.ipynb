# %% [markdown]
# # A Basic Weather Model made using RIDGE Regression
#
# A simple weather model using Ridge regression.

# %%
import sys
# !{sys.executable} -m pip install xgboost

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import xgboost as xgb
from sklearn.metrics import mean_squared_error
color_pal = sns.color_palette()

weather = pd.read_csv("Port of Spain.csv",index_col=0, encoding='latin1' )
weather.head(10)
# Out:
#             humidity  precipcover  windspeed  cloudcover  visibility  \
# datetime
# 2000-01-01      78.0          0.0       15.0        43.8         7.6
# 2000-01-02      83.7          0.0       16.1        57.9         8.2
# 2000-01-03      78.6          0.0       12.8        73.2         9.5
# 2000-01-04      84.9          0.0       13.9        77.7         9.7
# 2000-01-05      93.0          0.0       11.4        76.0         8.2
# 2000-01-06      86.7          0.0       18.3        80.0         6.8
# 2000-01-07      83.4          0.0       15.0        64.2         7.4
# 2000-01-08      75.8          0.0       13.9        42.2         8.4
# 2000-01-09      82.3          0.0       16.1        51.4         7.1
# 2000-01-10      78.8          0.0       18.3        42.4         8.5
#
#            sunrise_time sunset_time  Port of Spain precip mm  tempmax c  \
# datetime
# 2000-01-01     06:24:06    17:54:48                  9.77900       31.1
# ...

# %%
weather.apply(pd.isnull).sum()
# Out:
# humidity                   0
# precipcover                0
# windspeed                  0
# cloudcover                 0
# visibility                 0
# sunrise_time               0
# sunset_time                0
# Port of Spain precip mm    0
# tempmax c                  0
# tempmin c                  0
# avgtemp c                  0
# feelslikemax c             0
# feelslikemin c             0
# avgfeelsliketemp c         0
# dewpoint c                 0
# dtype: int64

# %%
weather.dtypes
# Out:
# humidity                   float64
# precipcover                float64
# windspeed                  float64
# cloudcover                 float64
# visibility                 float64
# sunrise_time                object
# sunset_time                 object
# Port of Spain precip mm    float64
# tempmax c                  float64
# tempmin c                  float64
# avgtemp c                  float64
# feelslikemax c             float64
# feelslikemin c             float64
# avgfeelsliketemp c         float64
# dewpoint c                 float64
# dtype: object

# %%
weather.drop(columns=['sunrise_time'],inplace=True)
weather.drop(columns=['sunset_time'],inplace=True)
weather.dtypes
# Out:
# humidity                   float64
# precipcover                float64
# windspeed                  float64
# cloudcover                 float64
# visibility                 float64
# Port of Spain precip mm    float64
# tempmax c                  float64
# tempmin c                  float64
# avgtemp c                  float64
# feelslikemax c             float64
# feelslikemin c             float64
# avgfeelsliketemp c         float64
# dewpoint c                 float64
# dtype: object

# %%
weather.index
# Out:
# Index(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04', '2000-01-05',
#        '2000-01-06', '2000-01-07', '2000-01-08', '2000-01-09', '2000-01-10',
#        ...
#        '2020-12-22', '2020-12-23', '2020-12-24', '2020-12-25', '2020-12-26',
#        '2020-12-27', '2020-12-28', '2020-12-29', '2020-12-30', '2020-12-31'],
#       dtype='object', name='datetime', length=7637)

# %%
weather.index = pd.to_datetime(weather.index)
weather.index
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08',
#                '2000-01-09', '2000-01-10',
#                ...
#                '2020-12-22', '2020-12-23', '2020-12-24', '2020-12-25',
#                '2020-12-26', '2020-12-27', '2020-12-28', '2020-12-29',
#                '2020-12-30', '2020-12-31'],
#               dtype='datetime64[ns]', name='datetime', length=7637, freq=None)

# %%
weather[["tempmax c", "tempmin c"]].plot()
# Out:
# <Axes: xlabel='datetime'>

# %%
weather.corr()
# Out:
#                          humidity  precipcover  windspeed  cloudcover  \
# humidity                 1.000000     0.100509  -0.267579    0.403003
# precipcover              0.100509     1.000000   0.033334   -0.110612
# windspeed               -0.267579     0.033334   1.000000   -0.145946
# cloudcover               0.403003    -0.110612  -0.145946    1.000000
# visibility              -0.168968    -0.278033  -0.195514    0.042818
# Port of Spain precip mm  0.430598     0.140316  -0.098371    0.192600
# tempmax c               -0.507214    -0.074204  -0.019695   -0.186095
# tempmin c                0.085850     0.080579   0.015615    0.144597
# avgtemp c               -0.471877    -0.050303   0.032140   -0.118827
# feelslikemax c           0.007339    -0.010344  -0.160260    0.020725
# feelslikemin c           0.082644     0.080394   0.017176    0.144035
# avgfeelsliketemp c      -0.279969    -0.039125  -0.041463   -0.052623
# ...

# %% [markdown]
# # Train Test Split

# %%
train = weather.loc[weather.index < '01-01-2017']
test = weather.loc[weather.index >= '01-01-2017']

fig, ax = plt.subplots(figsize=(15, 5))
train.plot(ax=ax, label='Training Set', title='Data Train/Test Split')
test.plot(ax=ax, label='Test Set')
ax.axvline('01-01-2017', color='black', ls='--')
ax.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.show()

# %%
features = ['avgtemp c','humidity','windspeed','cloudcover','visibility','Port of Spain precip mm','dewpoint c']

fig, ax = plt.subplots(figsize=(15, 5))
train[features].plot(ax=ax, label=[f'{col} (train)' for col in features])
test[features].plot(ax=ax, linestyle='--', label=[f'{col} (test)' for col in features])
ax.axvline('2017-01-01', color='black', ls='--', label='Train/Test Split')
ax.set_title('Data Train/Test Split')
ax.set_xlabel('datetime')
ax.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.tight_layout()
plt.show()

# %%
weather.loc[(weather.index > '07-01-2019') & (weather.index < '07-08-2019')] \
    .plot(figsize=(15, 5), title='Week Of Data')
plt.show()

# %% [markdown]
# # Create features

# %%
df = weather.copy()
df['dayofweek'] = df.index.dayofweek
df['dayofyear'] = df.index.dayofyear
df['month'] = df.index.month
df['year'] = df.index.year

fig, ax = plt.subplots(figsize=(10, 8))
sns.boxplot(data=df, x='month', y='tempmax c')
ax.set_title('TempMax by Month')
plt.show()

# %%
def create_features(df):
    df = df.copy()
    df['dayofweek'] = df.index.dayofweek
    df['dayofyear'] = df.index.dayofyear
    df['month'] = df.index.month
    df['year'] = df.index.year

    return df
df = create_features(weather)

fig, ax = plt.subplots(figsize=(10, 8))
sns.boxplot(data=df, x='month', y='tempmin c')
ax.set_title
# Out:
# <bound method Axes.set_title of <Axes: xlabel='month', ylabel='tempmin c'>>

# %%
df.head(10)
# Out:
#             humidity  precipcover  windspeed  cloudcover  visibility  \
# datetime
# 2000-01-01      78.0          0.0       15.0        43.8         7.6
# 2000-01-02      83.7          0.0       16.1        57.9         8.2
# 2000-01-03      78.6          0.0       12.8        73.2         9.5
# 2000-01-04      84.9          0.0       13.9        77.7         9.7
# 2000-01-05      93.0          0.0       11.4        76.0         8.2
# 2000-01-06      86.7          0.0       18.3        80.0         6.8
# 2000-01-07      83.4          0.0       15.0        64.2         7.4
# 2000-01-08      75.8          0.0       13.9        42.2         8.4
# 2000-01-09      82.3          0.0       16.1        51.4         7.1
# 2000-01-10      78.8          0.0       18.3        42.4         8.5
#
#             Port of Spain precip mm  tempmax c  tempmin c  avgtemp c  \
# datetime
# 2000-01-01                  9.77900       31.1       22.1       26.7
# ...

# %% [markdown]
# # Model

# %%
train = create_features(train)
test = create_features(test)

target = ['tempmax c', 'tempmin c', 'avgtemp c', 'feelslikemax c','feelslikemin c','avgfeelsliketemp c', 'dewpoint c','humidity','precipcover','windspeed','cloudcover','visibility']
features = ['dayofweek','dayofyear','month','year']

X_train = train[features]
y_train = train[target]

X_test = test[features]
y_test = test[target]

# %%
reg = xgb.XGBRegressor(base_score=0.5, booster='gbtree',    
                       n_estimators=1000,
                       early_stopping_rounds=50,
                       objective='reg:linear',
                       max_depth=3,
                       learning_rate=0.01)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        verbose=100)
# Out:
# [0]	validation_0-rmse:37.01458	validation_1-rmse:33.41745
# C:\Users\student\anaconda3\Lib\site-packages\xgboost\callback.py:386: UserWarning: [09:19:12] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\objective\regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   self.starting_round = model.num_boosted_rounds()
# [100]	validation_0-rmse:14.46275	validation_1-rmse:12.39213
# [200]	validation_0-rmse:7.27926	validation_1-rmse:5.30543
# [300]	validation_0-rmse:5.61174	validation_1-rmse:3.68571
# [400]	validation_0-rmse:5.30710	validation_1-rmse:3.60590
# [416]	validation_0-rmse:5.28929	validation_1-rmse:3.61626
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric=None, feature_types=None,
# ...

# %%
fi = pd.DataFrame(data=reg.feature_importances_,
             index=reg.feature_names_in_,
             columns=['importance'])
fi.sort_values('importance').plot(kind='barh', title='Feature Importance')
plt.show()

# %%
ptest = reg.predict(X_test)
ptest
# Out:
# array([[29.85229  , 22.19237  , 25.52223  , ..., 17.077932 , 41.02035  ,
#          6.6035748],
#        [29.903584 , 22.23853  , 25.52223  , ..., 17.065685 , 41.02035  ,
#          6.6035748],
#        [30.001139 , 22.239613 , 25.52223  , ..., 17.065685 , 41.02035  ,
#          6.6035748],
#        ...,
#        [30.675232 , 22.813879 , 25.742409 , ..., 18.016006 , 51.88384  ,
#          6.5195017],
#        [30.675232 , 22.813879 , 25.703957 , ..., 18.016006 , 52.212658 ,
#          6.5195017],
#        [30.675232 , 22.813879 , 25.703957 , ..., 18.016006 , 52.212658 ,
#          6.5195017]], dtype=float32)

# %%
# Evaluating the XGBoost model on the testing set

from sklearn.metrics import mean_absolute_error, mean_squared_error

mae = mean_absolute_error(y_test, ptest)

rmse = np.sqrt(mean_squared_error(y_test, ptest))

print(mae)
print(rmse)
# Out:
# 1.9896150080248702
# 3.5887129371050115

# %%
columns = df.columns

# Add each prediction as a new column in test
for i, col in enumerate(y_test.columns):
    test[f"{col}_prediction"] = ptest[:, i]

# %%
print(test.filter(like='_prediction').head(1))
# Out:
#             tempmax c_prediction  tempmin c_prediction  avgtemp c_prediction  \
# datetime
# 2017-01-01             29.852289             22.192369              25.52223
#
#             feelslikemax c_prediction  feelslikemin c_prediction  \
# datetime
# 2017-01-01                   33.26482                  22.188763
#
#             avgfeelsliketemp c_prediction  dewpoint c_prediction  \
# datetime
# 2017-01-01                      26.614721              21.696949
#
#             humidity_prediction  precipcover_prediction  windspeed_prediction  \
# datetime
# 2017-01-01            78.975243                4.505531             17.077932
#
#             cloudcover_prediction  visibility_prediction
# datetime
# 2017-01-01              41.020351               6.603575

# %%
fig, ax = plt.subplots(figsize=(15, 5))

category = 'avgtemp c'

# Plot actual data from df
df[category].plot(ax=ax, label='True Data', linewidth=2)

# Plot predictions from test
test[f"{category}_prediction"].plot(ax=ax, label='Prediction', alpha=0.7)

ax.set_title(f"{category}: True Data vs Prediction")
ax.set_xlabel("Date")
ax.set_ylabel(category)
ax.legend()

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15, 5))

category = 'avgtemp c'

# Actual humidity from original data
df.loc[(df.index > '07-01-2019') & (df.index < '07-08-2019'), category] \
    .plot(ax=ax, label=f"Actual {category}")

# Predicted humidity from model (test set)
test.loc[(test.index > '07-01-2019') & (test.index < '07-08-2019'), f"{category}_prediction"] \
    .plot(ax=ax, style='.', label=f"Predicted {category}")

# Labels and legend
ax.set_title(f"{category} vs Predicted {category} - Week of July 1, 2019")
ax.set_xlabel('Date')
ax.set_ylabel(category)
ax.legend()
plt.tight_layout()
plt.show()
