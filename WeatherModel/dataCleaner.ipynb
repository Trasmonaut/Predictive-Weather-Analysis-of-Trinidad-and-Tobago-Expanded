# %% [markdown]
# # Designed to Clean / Standardize any Dataset into a standard format

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import calendar
import string
from string import punctuation
from itertools import chain

from sklearn.model_selection import train_test_split
from sklearn.metrics import recall_score, f1_score

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.decomposition import NMF, LatentDirichletAllocation, TruncatedSVD
from sklearn.feature_selection import SelectPercentile, chi2, f_regression, f_classif

from sklearn import svm
from sklearn.utils import shuffle

df = pd.read_csv('Chaguanas_weather_data_2000_2025.csv', encoding='latin1')  #load Datafield csv
pd.options.mode.copy_on_write = True

# %% [markdown]
# # Read and Understand the Dataset

# %%
df.shape
# Out:
# (9463, 28)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9463 entries, 0 to 9462
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              9216 non-null   object
#  1   datetime          9216 non-null   object
#  2   tempmax           9216 non-null   float64
#  3   tempmin           9216 non-null   float64
#  4   temp              9216 non-null   float64
#  5   feelslikemax      9216 non-null   float64
#  6   feelslikemin      9216 non-null   float64
#  7   feelslike         9216 non-null   float64
#  8   dew               9216 non-null   float64
#  9   humidity          9216 non-null   float64
#  10  precip            7420 non-null   float64
#  11  precipprob        9216 non-null   float64
#  12  precipcover       9216 non-null   float64
#  13  windspeed         9216 non-null   float64
#  14  winddir           9186 non-null   float64
#  15  sealevelpressure  8934 non-null   float64
#  16  cloudcover        9216 non-null   float64
#  17  visibility        9213 non-null   float64
#  18  solarradiation    5597 non-null   float64
#  19  solarenergy       5597 non-null   float64
#  20  uvindex           5597 non-null   float64
#  21  sunrise           9216 non-null   object
#  22  sunset            9216 non-null   object
#  23  moonphase         9216 non-null   float64
#  24  conditions        9216 non-null   object
#  25  description       9216 non-null   object
#  26  icon              9216 non-null   object
#  27  stations          9216 non-null   object
# dtypes: float64(20), object(8)
# memory usage: 2.0+ MB

# %%
df.head(10)   #shows the first 10 rows of the CSV to highlight what the data looks like
# Out:
#                                        name    datetime  tempmax  tempmin  \
# 0  Chaguanas, Trinidad, Trinidad And Tobago  01/01/2000     87.9     71.7
# 1  Chaguanas, Trinidad, Trinidad And Tobago  02/01/2000     87.9     71.3
# 2  Chaguanas, Trinidad, Trinidad And Tobago  03/01/2000     89.7     73.5
# 3  Chaguanas, Trinidad, Trinidad And Tobago  04/01/2000     84.3     71.3
# 4  Chaguanas, Trinidad, Trinidad And Tobago  05/01/2000     81.2     73.1
# 5  Chaguanas, Trinidad, Trinidad And Tobago  06/01/2000     87.9     73.5
# 6  Chaguanas, Trinidad, Trinidad And Tobago  07/01/2000     87.5     73.5
# 7  Chaguanas, Trinidad, Trinidad And Tobago  08/01/2000     87.9     72.8
# 8  Chaguanas, Trinidad, Trinidad And Tobago  09/01/2000     87.9     71.7
# 9  Chaguanas, Trinidad, Trinidad And Tobago  10/01/2000     88.4     73.5
#
#    temp  feelslikemax  feelslikemin  feelslike   dew  humidity  ...  \
# 0  80.0          94.4          71.7       82.7  72.0      78.0  ...
# 1  78.2          96.1          71.3       80.5  72.5      83.7  ...
# 2  79.3          95.0          73.5       81.2  71.6      78.6  ...
# 3  76.1          89.8          71.3       77.2  70.9      84.9  ...
# 4  76.1          86.7          73.1       76.5  73.9      93.0  ...
# 5  77.9          96.1          73.5       79.7  73.4      86.7  ...
# 6  77.3          92.9          73.5       78.4  71.5      83.4  ...
# 7  79.7          92.9          72.8       81.6  70.6      75.8  ...
# 8  78.5          95.4          71.7       81.3  72.3      82.3  ...
# 9  79.6          95.7          73.5       82.0  71.9      78.8  ...
#
#    solarradiation  solarenergy  uvindex              sunrise  \
# 0             NaN          NaN      NaN  2000-01-01T06:23:33
# 1             NaN          NaN      NaN  2000-01-02T06:23:56
# 2             NaN          NaN      NaN  2000-01-03T06:24:20
# 3             NaN          NaN      NaN  2000-01-04T06:24:42
# 4             NaN          NaN      NaN  2000-01-05T06:25:04
# 5             NaN          NaN      NaN  2000-01-06T06:25:25
# 6             NaN          NaN      NaN  2000-01-07T06:25:45
# 7             NaN          NaN      NaN  2000-01-08T06:26:04
# 8             NaN          NaN      NaN  2000-01-09T06:26:23
# 9             NaN          NaN      NaN  2000-01-10T06:26:40
#
#                 sunset  moonphase        conditions  \
# 0  2000-01-01T17:54:34       0.83  Partially cloudy
# 1  2000-01-02T17:55:07       0.86  Partially cloudy
# 2  2000-01-03T17:55:40       0.90  Partially cloudy
# 3  2000-01-04T17:56:12       0.93  Partially cloudy
# 4  2000-01-05T17:56:45       0.96  Partially cloudy
# 5  2000-01-06T17:57:18       0.00  Partially cloudy
# 6  2000-01-07T17:57:50       0.03  Partially cloudy
# 7  2000-01-08T17:58:22       0.07  Partially cloudy
# 8  2000-01-09T17:58:55       0.10  Partially cloudy
# 9  2000-01-10T17:59:27       0.14  Partially cloudy
#
#                          description               icon     stations
# 0  Partly cloudy throughout the day.  partly-cloudy-day  78970099999
# 1  Partly cloudy throughout the day.  partly-cloudy-day  78970099999
# 2  Partly cloudy throughout the day.  partly-cloudy-day  78970099999
# 3         Clearing in the afternoon.  partly-cloudy-day  78970099999
# 4  Partly cloudy throughout the day.  partly-cloudy-day  78970099999
# 5  Partly cloudy throughout the day.  partly-cloudy-day  78970099999
# 6  Partly cloudy throughout the day.  partly-cloudy-day  78970099999
# 7  Partly cloudy throughout the day.  partly-cloudy-day  78970099999
# 8  Partly cloudy throughout the day.  partly-cloudy-day  78970099999
# 9  Partly cloudy throughout the day.  partly-cloudy-day  78970099999
#
# [10 rows x 28 columns]

# %%
df.describe()
# Out:
#            tempmax      tempmin         temp  feelslikemax  feelslikemin  \
# count  9216.000000  9216.000000  9216.000000   9216.000000   9216.000000
# mean     88.830827    74.802648    80.666667     97.361003     74.818218
# std       2.961867     2.302414     1.978656      5.231379      2.358029
# min      71.700000    37.300000    71.000000     71.700000     37.300000
# 25%      87.700000    73.400000    79.300000     93.700000     73.400000
# 50%      89.600000    75.200000    80.700000     97.550000     75.200000
# 75%      91.300000    76.700000    82.200000    100.600000     76.700000
# max     138.100000    80.600000    86.200000    138.100000     88.200000
#
#          feelslike          dew     humidity       precip   precipprob  \
# count  9216.000000  9216.000000  9216.000000  7420.000000  9216.000000
# mean     84.069390    73.381174    79.946832     0.185646    45.865885
# std       3.541462     2.453970     6.148005     0.443809    49.831501
# min      71.000000    62.100000    57.200000     0.000000     0.000000
# 25%      81.400000    71.700000    75.500000     0.000000     0.000000
# 50%      84.000000    73.900000    79.600000     0.012000     0.000000
# 75%      86.600000    75.300000    84.300000     0.161000   100.000000
# max      96.800000    79.100000    99.300000     9.134000   100.000000
#
#        precipcover    windspeed      winddir  sealevelpressure   cloudcover  \
# count  9216.000000  9216.000000  9186.000000       8934.000000  9216.000000
# mean      4.857348    15.207118    95.893033       1012.587620    58.408203
# std      12.565587     5.007551    32.097918          1.529799    17.982966
# min       0.000000     0.000000     0.100000       1006.000000    16.500000
# 25%       0.000000    12.800000    76.400000       1011.600000    43.500000
# 50%       0.000000    15.000000    96.400000       1012.700000    55.000000
# 75%       4.170000    17.200000   108.000000       1013.700000    73.800000
# max     100.000000   162.400000   360.000000       1017.600000   100.000000
#
#         visibility  solarradiation  solarenergy      uvindex    moonphase
# count  9213.000000     5597.000000  5597.000000  5597.000000  9216.000000
# mean      7.176359      219.639861    18.968698     7.712346     0.483228
# std       1.032494       55.851473     4.821172     1.673965     0.288573
# min       2.700000        0.000000     0.000000     0.000000     0.000000
# 25%       6.600000      184.500000    15.900000     7.000000     0.250000
# 50%       7.100000      230.000000    19.900000     8.000000     0.500000
# 75%       7.700000      263.200000    22.700000     9.000000     0.750000
# max      16.800000      328.700000    28.200000    10.000000     0.980000

# %%
df.isna()   # returns all Null values, where Null = true.
# Out:
#        name  datetime  tempmax  tempmin   temp  feelslikemax  feelslikemin  \
# 0     False     False    False    False  False         False         False
# 1     False     False    False    False  False         False         False
# 2     False     False    False    False  False         False         False
# 3     False     False    False    False  False         False         False
# 4     False     False    False    False  False         False         False
# ...     ...       ...      ...      ...    ...           ...           ...
# 9458   True      True     True     True   True          True          True
# 9459   True      True     True     True   True          True          True
# 9460   True      True     True     True   True          True          True
# 9461   True      True     True     True   True          True          True
# 9462   True      True     True     True   True          True          True
#
#       feelslike    dew  humidity  ...  solarradiation  solarenergy  uvindex  \
# 0         False  False     False  ...            True         True     True
# 1         False  False     False  ...            True         True     True
# 2         False  False     False  ...            True         True     True
# 3         False  False     False  ...            True         True     True
# 4         False  False     False  ...            True         True     True
# ...         ...    ...       ...  ...             ...          ...      ...
# 9458       True   True      True  ...            True         True     True
# 9459       True   True      True  ...            True         True     True
# 9460       True   True      True  ...            True         True     True
# 9461       True   True      True  ...            True         True     True
# 9462       True   True      True  ...            True         True     True
#
#       sunrise  sunset  moonphase  conditions  description   icon  stations
# 0       False   False      False       False        False  False     False
# 1       False   False      False       False        False  False     False
# 2       False   False      False       False        False  False     False
# 3       False   False      False       False        False  False     False
# 4       False   False      False       False        False  False     False
# ...       ...     ...        ...         ...          ...    ...       ...
# 9458     True    True       True        True         True   True      True
# 9459     True    True       True        True         True   True      True
# 9460     True    True       True        True         True   True      True
# 9461     True    True       True        True         True   True      True
# 9462     True    True       True        True         True   True      True
#
# [9463 rows x 28 columns]

# %%
df.isna().sum()
# Out:
# name                 247
# datetime             247
# tempmax              247
# tempmin              247
# temp                 247
# feelslikemax         247
# feelslikemin         247
# feelslike            247
# dew                  247
# humidity             247
# precip              2043
# precipprob           247
# precipcover          247
# windspeed            247
# winddir              277
# sealevelpressure     529
# cloudcover           247
# visibility           250
# solarradiation      3866
# solarenergy         3866
# uvindex             3866
# sunrise              247
# sunset               247
# moonphase            247
# conditions           247
# description          247
# icon                 247
# stations             247
# dtype: int64

# %%
for col in df.columns:
    print(col,df[col].nunique())
# Out:
# name 1
# datetime 9216
# tempmax 143
# tempmin 107
# temp 123
# feelslikemax 303
# feelslikemin 121
# feelslike 220
# dew 149
# humidity 342
# precip 659
# precipprob 2
# precipcover 25
# windspeed 133
# winddir 1202
# sealevelpressure 102
# cloudcover 716
# visibility 102
# solarradiation 1981
# solarenergy 241
# uvindex 11
# sunrise 9216
# sunset 9216
# moonphase 96
# conditions 5
# description 32
# icon 5
# stations 19

# %% [markdown]
# # Basic Data Preprocessing
#
# Sunrise / sunset data convereted to just only contain time in 24 hour format.
# Icon / Station / wind direction / sea pressure data was removed as deemed unncessary.
# Tempratures converted to C from F.
# Onehat Encoding for Condition.
# Season Categroy added, converting it to Wet and Dry.
# Precip converted from Inches to MM.
# name truncated to only location (example port of spain)

# %% [raw]
# Replace Missing Values

# %%
df.apply(pd.isnull).sum()/df.shape[0]
# Out:
# name                0.026102
# datetime            0.026102
# tempmax             0.026102
# tempmin             0.026102
# temp                0.026102
# feelslikemax        0.026102
# feelslikemin        0.026102
# feelslike           0.026102
# dew                 0.026102
# humidity            0.026102
# precip              0.215893
# precipprob          0.026102
# precipcover         0.026102
# windspeed           0.026102
# winddir             0.029272
# sealevelpressure    0.055902
# cloudcover          0.026102
# visibility          0.026419
# solarradiation      0.408539
# solarenergy         0.408539
# uvindex             0.408539
# sunrise             0.026102
# sunset              0.026102
# moonphase           0.026102
# conditions          0.026102
# description         0.026102
# icon                0.026102
# stations            0.026102
# dtype: float64

# %%
df["precip"].value_counts() / df.shape[0]
# Out:
# precip
# 0.000    0.337419
# 0.039    0.026313
# 0.079    0.023354
# 0.012    0.021980
# 0.004    0.020501
#            ...
# 0.239    0.000106
# 0.400    0.000106
# 0.160    0.000106
# 0.195    0.000106
# 0.732    0.000106
# Name: count, Length: 659, dtype: float64

# %%
df.drop(columns=['icon'],inplace=True)
df.drop(columns=['stations'],inplace=True)
df.drop(columns=['winddir'],inplace=True)
df.drop(columns=['sealevelpressure'],inplace=True)
df.drop(columns=['description'],inplace=True)
df.drop(columns=['conditions'],inplace=True)
df.drop(columns=['solarradiation'],inplace=True)
df.drop(columns=['solarenergy'],inplace=True)
df.drop(columns=['uvindex'],inplace=True)
df.drop(columns=['moonphase'],inplace=True)
df.drop(columns=['sunrise'],inplace=True)
df.drop(columns=['sunset'],inplace=True)
df.drop(columns=['precipcover'], inplace=True)

df.head(10)
# Out:
#                                        name    datetime  tempmax  tempmin  \
# 0  Chaguanas, Trinidad, Trinidad And Tobago  01/01/2000     87.9     71.7
# 1  Chaguanas, Trinidad, Trinidad And Tobago  02/01/2000     87.9     71.3
# 2  Chaguanas, Trinidad, Trinidad And Tobago  03/01/2000     89.7     73.5
# 3  Chaguanas, Trinidad, Trinidad And Tobago  04/01/2000     84.3     71.3
# 4  Chaguanas, Trinidad, Trinidad And Tobago  05/01/2000     81.2     73.1
# 5  Chaguanas, Trinidad, Trinidad And Tobago  06/01/2000     87.9     73.5
# 6  Chaguanas, Trinidad, Trinidad And Tobago  07/01/2000     87.5     73.5
# 7  Chaguanas, Trinidad, Trinidad And Tobago  08/01/2000     87.9     72.8
# 8  Chaguanas, Trinidad, Trinidad And Tobago  09/01/2000     87.9     71.7
# 9  Chaguanas, Trinidad, Trinidad And Tobago  10/01/2000     88.4     73.5
#
#    temp  feelslikemax  feelslikemin  feelslike   dew  humidity  precip  \
# 0  80.0          94.4          71.7       82.7  72.0      78.0     NaN
# 1  78.2          96.1          71.3       80.5  72.5      83.7     NaN
# 2  79.3          95.0          73.5       81.2  71.6      78.6     NaN
# 3  76.1          89.8          71.3       77.2  70.9      84.9     NaN
# 4  76.1          86.7          73.1       76.5  73.9      93.0     NaN
# 5  77.9          96.1          73.5       79.7  73.4      86.7     NaN
# 6  77.3          92.9          73.5       78.4  71.5      83.4     NaN
# 7  79.7          92.9          72.8       81.6  70.6      75.8     NaN
# 8  78.5          95.4          71.7       81.3  72.3      82.3     NaN
# 9  79.6          95.7          73.5       82.0  71.9      78.8     NaN
#
#    precipprob  windspeed  cloudcover  visibility
# 0         0.0       15.0        43.8         7.6
# 1         0.0       16.1        57.9         8.2
# 2         0.0       12.8        73.2         9.5
# 3         0.0       13.9        77.7         9.7
# 4         0.0       11.4        76.0         8.2
# 5         0.0       18.3        80.0         6.8
# 6         0.0       15.0        64.2         7.4
# 7         0.0       13.9        42.2         8.4
# 8         0.0       16.1        51.4         7.1
# 9         0.0       18.3        42.4         8.5

# %% [markdown]
# Convert rain to mm

# %%
def inches_to_mm(inches):
    return inches * 25.4

df['precip'] = df['precip'].apply(lambda x: pd.Series(inches_to_mm(x)))
df.rename(columns={"windspeed": "windspeed mph"})

df.head(10)
# Out:
#                                        name    datetime  tempmax  tempmin  \
# 0  Chaguanas, Trinidad, Trinidad And Tobago  01/01/2000     87.9     71.7
# 1  Chaguanas, Trinidad, Trinidad And Tobago  02/01/2000     87.9     71.3
# 2  Chaguanas, Trinidad, Trinidad And Tobago  03/01/2000     89.7     73.5
# 3  Chaguanas, Trinidad, Trinidad And Tobago  04/01/2000     84.3     71.3
# 4  Chaguanas, Trinidad, Trinidad And Tobago  05/01/2000     81.2     73.1
# 5  Chaguanas, Trinidad, Trinidad And Tobago  06/01/2000     87.9     73.5
# 6  Chaguanas, Trinidad, Trinidad And Tobago  07/01/2000     87.5     73.5
# 7  Chaguanas, Trinidad, Trinidad And Tobago  08/01/2000     87.9     72.8
# 8  Chaguanas, Trinidad, Trinidad And Tobago  09/01/2000     87.9     71.7
# 9  Chaguanas, Trinidad, Trinidad And Tobago  10/01/2000     88.4     73.5
#
#    temp  feelslikemax  feelslikemin  feelslike   dew  humidity  precip  \
# 0  80.0          94.4          71.7       82.7  72.0      78.0     NaN
# 1  78.2          96.1          71.3       80.5  72.5      83.7     NaN
# 2  79.3          95.0          73.5       81.2  71.6      78.6     NaN
# 3  76.1          89.8          71.3       77.2  70.9      84.9     NaN
# 4  76.1          86.7          73.1       76.5  73.9      93.0     NaN
# 5  77.9          96.1          73.5       79.7  73.4      86.7     NaN
# 6  77.3          92.9          73.5       78.4  71.5      83.4     NaN
# 7  79.7          92.9          72.8       81.6  70.6      75.8     NaN
# 8  78.5          95.4          71.7       81.3  72.3      82.3     NaN
# 9  79.6          95.7          73.5       82.0  71.9      78.8     NaN
#
#    precipprob  windspeed  cloudcover  visibility
# 0         0.0       15.0        43.8         7.6
# 1         0.0       16.1        57.9         8.2
# 2         0.0       12.8        73.2         9.5
# 3         0.0       13.9        77.7         9.7
# 4         0.0       11.4        76.0         8.2
# 5         0.0       18.3        80.0         6.8
# 6         0.0       15.0        64.2         7.4
# 7         0.0       13.9        42.2         8.4
# 8         0.0       16.1        51.4         7.1
# 9         0.0       18.3        42.4         8.5

# %% [markdown]
# Convert Degrees

# %%
def fahrenheit_to_celsius(fahrenheit):
    celsius = (fahrenheit - 32) * 5 / 9
    return round(celsius, 1)


df[[ 'tempmax c']] = df ['tempmax'].apply(lambda x: pd.Series(fahrenheit_to_celsius(x)))
df[[ 'tempmin c']] = df ['tempmin'].apply(lambda x: pd.Series(fahrenheit_to_celsius(x)))
df[[ 'avgtemp c']] = df ['temp'].apply(lambda x: pd.Series(fahrenheit_to_celsius(x)))

df[[ 'feelslikemax c']] = df ['feelslikemax'].apply(lambda x: pd.Series(fahrenheit_to_celsius(x)))
df[[ 'feelslikemin c']] = df ['feelslikemin'].apply(lambda x: pd.Series(fahrenheit_to_celsius(x)))
df[[ 'avgfeelsliketemp c']] = df ['feelslike'].apply(lambda x: pd.Series(fahrenheit_to_celsius(x)))

df[[ 'dewpoint c']] = df ['dew'].apply(lambda x: pd.Series(fahrenheit_to_celsius(x)))

df.drop(columns=['temp'],inplace=True)
df.drop(columns=['tempmax'],inplace=True)
df.drop(columns=['tempmin'],inplace=True)

df.drop(columns=['feelslike'],inplace=True)
df.drop(columns=['feelslikemax'],inplace=True)
df.drop(columns=['feelslikemin'],inplace=True)
df.drop(columns=['dew'],inplace=True)

df.head(10)
# Out:
#                                        name    datetime  humidity  precip  \
# 0  Chaguanas, Trinidad, Trinidad And Tobago  01/01/2000      78.0     NaN
# 1  Chaguanas, Trinidad, Trinidad And Tobago  02/01/2000      83.7     NaN
# 2  Chaguanas, Trinidad, Trinidad And Tobago  03/01/2000      78.6     NaN
# 3  Chaguanas, Trinidad, Trinidad And Tobago  04/01/2000      84.9     NaN
# 4  Chaguanas, Trinidad, Trinidad And Tobago  05/01/2000      93.0     NaN
# 5  Chaguanas, Trinidad, Trinidad And Tobago  06/01/2000      86.7     NaN
# 6  Chaguanas, Trinidad, Trinidad And Tobago  07/01/2000      83.4     NaN
# 7  Chaguanas, Trinidad, Trinidad And Tobago  08/01/2000      75.8     NaN
# 8  Chaguanas, Trinidad, Trinidad And Tobago  09/01/2000      82.3     NaN
# 9  Chaguanas, Trinidad, Trinidad And Tobago  10/01/2000      78.8     NaN
#
#    precipprob  windspeed  cloudcover  visibility  tempmax c  tempmin c  \
# 0         0.0       15.0        43.8         7.6       31.1       22.1
# 1         0.0       16.1        57.9         8.2       31.1       21.8
# 2         0.0       12.8        73.2         9.5       32.1       23.1
# 3         0.0       13.9        77.7         9.7       29.1       21.8
# 4         0.0       11.4        76.0         8.2       27.3       22.8
# 5         0.0       18.3        80.0         6.8       31.1       23.1
# 6         0.0       15.0        64.2         7.4       30.8       23.1
# 7         0.0       13.9        42.2         8.4       31.1       22.7
# 8         0.0       16.1        51.4         7.1       31.1       22.1
# 9         0.0       18.3        42.4         8.5       31.3       23.1
#
#    avgtemp c  feelslikemax c  feelslikemin c  avgfeelsliketemp c  dewpoint c
# 0       26.7            34.7            22.1                28.2        22.2
# 1       25.7            35.6            21.8                26.9        22.5
# 2       26.3            35.0            23.1                27.3        22.0
# 3       24.5            32.1            21.8                25.1        21.6
# 4       24.5            30.4            22.8                24.7        23.3
# 5       25.5            35.6            23.1                26.5        23.0
# 6       25.2            33.8            23.1                25.8        21.9
# 7       26.5            33.8            22.7                27.6        21.4
# 8       25.8            35.2            22.1                27.4        22.4
# 9       26.4            35.4            23.1                27.8        22.2

# %%
df = df.fillna(method="ffill")
# Out:
# C:\Users\cramd\AppData\Local\Temp\ipykernel_29532\567689999.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method="ffill")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9463 entries, 0 to 9462
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   name                9463 non-null   object
#  1   datetime            9463 non-null   object
#  2   humidity            9463 non-null   float64
#  3   precip              7667 non-null   float64
#  4   precipprob          9463 non-null   float64
#  5   windspeed           9463 non-null   float64
#  6   cloudcover          9463 non-null   float64
#  7   visibility          9463 non-null   float64
#  8   tempmax c           9463 non-null   float64
#  9   tempmin c           9463 non-null   float64
#  10  avgtemp c           9463 non-null   float64
#  11  feelslikemax c      9463 non-null   float64
#  12  feelslikemin c      9463 non-null   float64
#  13  avgfeelsliketemp c  9463 non-null   float64
#  14  dewpoint c          9463 non-null   float64
# dtypes: float64(13), object(2)
# memory usage: 1.1+ MB

# %%
for col in df.columns:
    print(col,df[col].nunique())
# Out:
# name 1
# datetime 9216
# humidity 342
# precip 659
# precipprob 2
# windspeed 133
# cloudcover 716
# visibility 102
# tempmax c 106
# tempmin c 72
# avgtemp c 72
# feelslikemax c 189
# feelslikemin c 83
# avgfeelsliketemp c 128
# dewpoint c 88

# %%
df.isna().sum()
# Out:
# name                     0
# datetime                 0
# humidity                 0
# precip                1796
# precipprob               0
# windspeed                0
# cloudcover               0
# visibility               0
# tempmax c                0
# tempmin c                0
# avgtemp c                0
# feelslikemax c           0
# feelslikemin c           0
# avgfeelsliketemp c       0
# dewpoint c               0
# dtype: int64

# %% [markdown]
# # Outlier Temprature Analysis
# Max Temp Ever Recorded in Triniad : 37.8
# Lowest Temp Ever Recorded in Trinidad : 16.1
#
# https://www.metoffice.gov.tt/Climate#:~:text=The%20coolest%20minimum%20temperature%20is,and%2030th%2C%201964%20at%20Piarco.

# %% [markdown]
# Backfill null values with avg for that day to avoid squewing data

# %%
df["datetime"] = pd.to_datetime(df["datetime"], format='mixed' ,dayfirst=True)
df["day"] = df["datetime"].dt.day
df["month"] = df["datetime"].dt.month
df["year"] = df["datetime"].dt.year

ref_df = df.loc['01/0/2005':'31/12/2025']

day_avg_precip = (ref_df[ref_df['precip'].notna()].groupby(['month', 'day'])['precip'].mean())
missing_mask = (df.year <= 2004) & (df['precip'].isna())
df.loc[missing_mask, 'precip'] = df[missing_mask].apply(lambda row: day_avg_precip.get((row['month'], row['day']), None),axis=1)

# %%
df.drop(columns=['precipprob'], inplace=True)
df['precip_chance'] = (df['precip'] > 0.00).astype(int)

# %% [markdown]
# Replace outliers with more than 36C actual temp with average for that day

# %%
day_avg_tempmax = df[df['tempmax c'] <= 37.8].groupby(['month', 'day'])['tempmax c'].mean()

mask = df['tempmax c'] > 37.8

df.loc[mask, 'tempmax c'] = df[mask].apply(
    lambda row: day_avg_tempmax.get((row['month'], row['day']), row['tempmax c']),
    axis=1
)

# %% [markdown]
# Replace outlier mintemp < 16.1 with average for that day

# %%
day_avg_tempmin = df[df['tempmin c'] >= 16.1].groupby(['month', 'day'])['tempmin c'].mean()

mask = df['tempmin c'] < 16.1

df.loc[mask, 'tempmin c'] = df[mask].apply(
    lambda row: day_avg_tempmin.get((row['month'], row['day']), row['tempmin c']),
    axis=1
)

# %% [markdown]
# # Replace outlier feelsmintemp < 16.1 with average for that day

# %%
day_avg_tempminfeellike = df[df['feelslikemin c'] >= 16.1].groupby(['month', 'day'])['feelslikemin c'].mean()

mask = df['feelslikemin c'] < 16.1

df.loc[mask, 'feelslikemin c'] = df[mask].apply(
    lambda row: day_avg_tempminfeellike.get((row['month'], row['day']), row['feelslikemin c']),
    axis=1
)
df.drop(columns=['month', 'day', 'year'], inplace=True)

# %%
# Ensure 'datetime' column is a datetime type
df['datetime'] = pd.to_datetime(df['datetime'], errors='coerce')

# Filter out rows before 2005
df = df[df['datetime'] >= '2005-01-01']

# %%
def rename_all_columns():
    df['name'] = df['name'].apply(lambda x: x.split(',')[0].strip())
    location = df['name'].iloc[0]

    return location

# Run function and save cleaned file
location = rename_all_columns()
fname = f'{location} cleaned.csv'
df.to_csv(fname, index=False)

# %%
df.isna().sum()
# Out:
# name                  0
# datetime              0
# humidity              0
# precip                0
# windspeed             0
# cloudcover            0
# visibility            0
# tempmax c             0
# tempmin c             0
# avgtemp c             0
# feelslikemax c        0
# feelslikemin c        0
# avgfeelsliketemp c    0
# dewpoint c            0
# precip_chance         0
# dtype: int64
